# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

# Load your data — if from file
# df = pd.read_csv("your_data.tsv", sep="\t")

# Or paste directly as a string (this example assumes you've saved it in 'data.tsv')
df = pd.read_csv("mfs.kstar.results.tsv", sep="\t")

# Extract mutation label from the Sequence column
def extract_mutation_label(seq):
    # extract just the mutations in order of B3, B5, B9, B14
    match = re.findall(r'B3=\w+|B5=\w+|B9=\w+|B14=\w+', seq)
    sorted_match = sorted(match, key=lambda x: int(x[1:x.find('=')]))  # sort by number (B3, B5, etc.)
    return ', '.join(sorted_match)

df['Mutation'] = df['Sequence'].apply(extract_mutation_label)

# Sort by K* upper bound for readability
df = df.sort_values(by='K* Upper (log10)', ascending=True)

# Plotting
x = np.arange(len(df))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 7))
bar1 = ax.bar(x - width/2, df['K* Lower Bound'], width, label='Lower Bound', color='steelblue')
bar2 = ax.bar(x + width/2, df['K* Upper Bound'], width, label='Upper Bound', color='orange')

ax.set_ylabel('K* Score')
ax.set_title('K* Score (log₁₀) for Mutations at B3, B5, B9, B14')
ax.set_xticks(x)
ax.set_xticklabels(df['Mutation'], rotation=90)
ax.legend()
plt.tight_layout()
plt.show()

# %%
df
# Out:
#     Seq ID                      Sequence  K* Lower Bound  K* Upper Bound  \
# 7        7  B3=leu B5=GLY B9=val B14=lys             0.0             0.0
# 9        9  B3=leu B5=ALA B9=val B14=lys             0.0             0.0
# 8        8  B3=leu B5=ASN B9=val B14=lys             0.0             0.0
# 4        4  B3=leu B5=arg B9=GLY B14=lys             0.0             0.0
# 10      10  B3=GLY B5=arg B9=val B14=lys             0.0             0.0
# 6        6  B3=leu B5=arg B9=ALA B14=lys             0.0             0.0
# 5        5  B3=leu B5=arg B9=ASN B14=lys             0.0             0.0
# 12      12  B3=ALA B5=arg B9=val B14=lys             0.0             0.0
# 11      11  B3=ASN B5=arg B9=val B14=lys             0.0             0.0
# 0        0  B3=leu B5=arg B9=val B14=lys             0.0             0.0
# 1        1  B3=leu B5=arg B9=val B14=GLY             0.0             0.0
# 3        3  B3=leu B5=arg B9=val B14=ALA             0.0             0.0
# 2        2  B3=leu B5=arg B9=val B14=ASN             0.0             0.0
#
#     K* Lower (log10)  K* Upper (log10)  Total # Confs.  Complex Pfunc Lower  \
# 7        -624.002036       -623.913578              12                  0.0
# 9        -623.846838       -623.770182              13                  0.0
# 8        -623.382639       -623.014181              15                  0.0
# 4        -621.350108       -621.045105              12                  0.0
# 10       -620.713560       -620.493352              15                  0.0
# 6        -620.427514       -620.195445              15                  0.0
# 5        -620.484784       -619.836289              21                  0.0
# 12       -619.859599       -619.641262              15                  0.0
# 11       -620.070329       -619.610865              16                  0.0
# 0        -619.583061       -618.891320              15                  0.0
# 1        -618.530846       -618.273979              13                  0.0
# 3        -618.438183       -618.169290              12                  0.0
# 2        -618.367469       -617.919042              13                  0.0
#
#     Complex Pfunc Upper  Complex Free Energy Lower  ...  Protein Epsilon  \
# 7                   0.0                 836.952815  ...              0.0
# 9                   0.0                 836.453598  ...              0.0
# 8                   0.0                 834.737227  ...              0.0
# 4                   0.0                 832.029013  ...              0.0
# 10                  0.0                 829.424376  ...              0.0
# 6                   0.0                 829.836065  ...              0.0
# 5                   0.0                 827.667858  ...              0.0
# 12                  0.0                 827.985755  ...              0.0
# 11                  0.0                 827.192175  ...              0.0
# 0                   0.0                 825.978828  ...              0.0
# 1                   0.0                 826.601527  ...              0.0
# 3                   0.0                 826.006275  ...              0.0
# 2                   0.0                 824.058088  ...              0.0
#
#     Protein # Confs.  Ligand Pfund Lower  Ligand Pfund Upper  \
# 7                  1        1.017662e+11        1.173486e+11
# 9                  1        1.697413e+11        1.957246e+11
# 8                  1        5.378937e+11        1.015407e+12
# 4                  1        5.557286e+11        6.920125e+11
# 10                 1        1.260381e+13        1.277418e+13
# 6                  1        3.170392e+12        3.804552e+12
# 5                  1        5.367215e+13        1.117524e+14
# 12                 1        2.004122e+13        2.031007e+13
# 11                 1        7.123124e+13        1.199584e+14
# 0                  1        1.051157e+14        2.761209e+14
# 1                  1        8.878114e+12        1.324267e+13
# 3                  1        1.903436e+13        2.787666e+13
# 2                  1        2.857324e+14        5.731104e+14
#
#     Ligand Free Energy Lower  Ligand Free Energy Upper  Ligand Epsilon  \
# 7                 -15.115909                -15.031416        0.132787
# 9                 -15.419289                -15.334819        0.132754
# 8                 -16.395649                -16.018835        0.470268
# 4                 -16.168249                -16.038179        0.196939
# 10                -17.897333                -17.889370        0.013337
# 6                 -17.179014                -17.070876        0.166685
# 5                 -19.183575                -18.748638        0.519722
# 12                -18.172325                -18.164422        0.013237
# 11                -19.225599                -18.916493        0.406201
# 0                 -19.720021                -19.147267        0.619313
# 1                 -17.918694                -17.681560        0.329583
# 3                 -18.360128                -18.133853        0.317194
# 2                 -20.153090                -19.740313        0.501436
#
#     Ligand # Confs.  Time (sec)                         Mutation
# 7                 6          26  B3=leu, B5=GLY, B9=val, B14=lys
# 9                 6          29  B3=leu, B5=ALA, B9=val, B14=lys
# 8                 8          28  B3=leu, B5=ASN, B9=val, B14=lys
# 4                 5          18  B3=leu, B5=arg, B9=GLY, B14=lys
# 10                6          32  B3=GLY, B5=arg, B9=val, B14=lys
# 6                 6          25  B3=leu, B5=arg, B9=ALA, B14=lys
# 5                 9          22  B3=leu, B5=arg, B9=ASN, B14=lys
# 12                6          39  B3=ALA, B5=arg, B9=val, B14=lys
# 11                7          36  B3=ASN, B5=arg, B9=val, B14=lys
# 0                 8          10  B3=leu, B5=arg, B9=val, B14=lys
# 1                 6          12  B3=leu, B5=arg, B9=val, B14=GLY
# 3                 6          15  B3=leu, B5=arg, B9=val, B14=ALA
# 2                 6          14  B3=leu, B5=arg, B9=val, B14=ASN
#
# [13 rows x 27 columns]
